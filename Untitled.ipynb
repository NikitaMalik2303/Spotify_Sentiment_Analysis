# %% [markdown]
# # Importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import nltk
import re
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer 
import seaborn as sns
from wordcloud import WordCloud

# %% [markdown]
# # Importing Dataset

# %%
data = pd.read_csv("reviews.csv", usecols = ["Review","Rating"])
data.head()
# Out:
#                                               Review  Rating
# 0  Great music service, the audio is high quality...       5
# 1  Please ignore previous negative rating. This a...       5
# 2  This pop-up "Get the best Spotify experience o...       4
# 3    Really buggy and terrible to use as of recently       1
# 4  Dear Spotify why do I get songs that I didn't ...       1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61594 entries, 0 to 61593
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Review  61594 non-null  object
#  1   Rating  61594 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 962.5+ KB

# %% [markdown]
# # Cleaning Data

# %%
length = len(data.index)
corpus = []
lem = WordNetLemmatizer()
for i in range(2000):
    review = re.sub("[^a-zA-Z0-9-+ ]", " ", data["Review"][i])
    review = review.lower()    
    review = review.split()
    review = [lem.lemmatize(word) for word in review if word not in set(stopwords.words("english"))]
    review = " ".join(str(j) for j in review)
    corpus.append(review)

# %%
print(corpus)
# Out:
# ['great music service audio high quality app easy use also quick friendly support', 'please ignore previous negative rating app super great give five stars+', 'pop-up get best spotify experience android 12 annoying please let get rid', 'really buggy terrible use recently', 'dear spotify get song put playlist shuffle play', 'player control sometimes disappear reason app restart forgets playing fix issue', 'love selection lyric provided song listening', 'still extremely slow changing storage external sd card convinced done purpose spotify know issue done nothing solve time changed sd card faster read write speed samsung brand please add like song never appear search playlist', 'great app best mp3 music app ever used one problem play song find song despite app wonderful recommend best', 'deleting app following reason app failing business model whether streaming service like consumer want pay music fully 6 ad successively upon logging single song much closed app ad number 6 patient way profit already peaked left decline', 'love spotify usually app best others stated control button disappear podcasts stop reason fixed deleting reinstalling app first world problem sure highly annoying nonetheless especially paying prime', 'play spotify wifi', 'amazon premium music family package good everyone could listen whatever liked respective alexas room asking play problem spotify premium family alexa integration poor like spotify stop playing time play different alexa device time asking integration better', 'worst app always say offline never showed song podcast', 'hav music like super', 'improve ia recommend song find similar song best music app youtube better everything else spotify king', 'android user - load glitch app player bar disappears shuffle button missing sort please', 'listen downloaded playlist offline point feature disappointed', 'always crashing unable play stop working everytime use', 'know ad cost free use yes thats right 3 ad straight back back like 1 hlaf minute sometimes think little much even volume increase ad', 'always favorite platform listen music like subscribe alot thing one must', 'voice sweet hearable', 'logged acc tried open log open see logo', 'usually love app problem everyone else reporting random pause stop playing restart currently view song podcast currently playing pause skip back forth fairly unusable stage acceptable paid service', 'amazing music experience', 'like everything like listen commercial even better even like song wanting knowing name brought thanks spotify', 'jammin hyuh old school hardcore thrash heard year return youth yes please', 'cant listen downloaded stuff offline', 'app show internet available phone wifi data working already fred add happens time want search song', 'everything perfect add light theme', 'option delete song album option download one track album option shuffle music library without creating playlist liking music', 'best music app ever seen', 'wow sudden login work even though 100 positive correct morning app asks login happened obviously problem found email account telling change password suspicious behaviour yeah logging spotify xbox suspicious thanks stress morning need renewing way teaching lesson', 'unable use ph get downloaded unable log', 'plz remove add ther continuously 2 3 add list remove 2 add give 1 add', 'liked song play offline help signal problem', 'sometimes try listen playlist play first song try go different one go back first one little weird', 'good app listening music', 'commercial add need wifi use satellite radio station pick least look', 'wide range song collection', 'deal compared desktop version inferior ability play song bare barely free need said think made point clear enough', 'spotify awesome love obscure artist think fingertip well easy access newer thing update lost star constantly asking review already done', 'best app stream music', 'account glitching logged try fix let log back show logo never sign screen', 'everything go open app last w ...

# %% [markdown]
# # EDA

# %%
sns.histplot(data["Rating"])
plt.show()

# %%
def transform_rating(rating):
    if rating == 4 or rating ==5:
        return "Positive"
    if rating == 3 :
        return "Neutral"
    if rating == 1 or rating ==2:
        return "Negative"

# %%
data["Rating"] = data["Rating"].apply(transform_rating)

# %%
sns.histplot(data["Rating"])
plt.xlabel("Ratings")
plt.ylabel("No of Ratings")
plt.title("Ratings Distribution")
plt.show()

# %% [markdown]
# # Splitting the dataset

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer()
X = cv.fit_transform(corpus).toarray()
Y = data.iloc[:2000,-1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size = 0.15, random_state = 0)

# %% [markdown]
# # WordCloud

# %%
positive = [corpus[i] for i in range(len(Y)) if Y[i] == "Positive"] 
plt.figure(figsize=(10,10))
wc = WordCloud(width = 1000, height = 600,background_color = "white", max_words = 2500, min_font_size = 12 ).generate(" ".join(positive))
plt.imshow(wc)

# %%
negative = [corpus[i] for i in range(len(Y)) if Y[i] == "Negative"]
plt.figure(figsize = (10,10))
wc = WordCloud(width = 1000, height = 600,background_color = "white", max_words = 2500, min_font_size = 12 ).generate(" ".join(negative))
plt.imshow(wc)

# %%
neutral = [corpus[i] for i in range(len(Y)) if Y[i] == "Neutral"]
plt.figure(figsize = (10,10))
wc = WordCloud(height = 600, width = 1000, background_color = "white", max_words = 2500, min_font_size = 12).generate(" ".join(neutral))
plt.imshow(wc)
